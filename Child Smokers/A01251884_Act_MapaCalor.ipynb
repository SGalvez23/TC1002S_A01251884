# %%
import numpy as np
import matplotlib.pyplot as plt 
import pandas as pd  
import seaborn as sns

# %%
cs = pd.read_csv('Child smokers.csv', na_values = ':')
cs
# Out:
#      Age (years)  Height (cm)  FEV (litres)     Sex  Smoker
# 0              9          145         1.708  female     non
# 1              8          171         1.724  female     non
# 2              7          138         1.720  female     non
# 3              9          135         1.558    male     non
# 4              9          145         1.895    male     non
# ..           ...          ...           ...     ...     ...
# 649           15          152         2.278  female  smoker
# 650           16          183         4.872    male  smoker
# 651           16          170         4.270    male  smoker
# 652           15          173         3.727    male  smoker
# 653           16          160         2.795  female  smoker
#
# [654 rows x 5 columns]

# %%
sns.set(rc={'figure.figsize':(12,9)})
sns.distplot(cs['Age (years)'], bins = 48)
plt.show()
# Out:
# /home/sebastian/anaconda3/lib/python3.8/site-packages/seaborn/distributions.py:2551: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %%
sns.set(rc={'figure.figsize':(12,9)})
sns.distplot(cs['Height (cm)'], bins = 48)
plt.show()
# Out:
# /home/sebastian/anaconda3/lib/python3.8/site-packages/seaborn/distributions.py:2551: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %%
sns.set(rc={'figure.figsize':(12,9)})
sns.distplot(cs['FEV (litres)'], bins = 48)
plt.show()
# Out:
# /home/sebastian/anaconda3/lib/python3.8/site-packages/seaborn/distributions.py:2551: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %%
correlation_matrix = cs.corr().round(2)
sns.heatmap(data=correlation_matrix, annot=True)
# Out:
# <AxesSubplot:>

# %%
cs = cs.dropna()

# %%
fig = plt.figure(figsize = (15, 10))
plt.boxplot(cs['Age (years)'], notch=True)
plt.title('Edad')
plt.show()

# %%
fig = plt.figure(figsize = (15, 10))
plt.boxplot(cs['Height (cm)'], notch=True)
plt.title('Altura')
plt.show()

# %%
fig = plt.figure(figsize = (15, 10))
plt.boxplot(cs['FEV (litres)'], notch=True)
plt.title('FEV')
plt.show()
